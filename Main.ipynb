# %%
import numpy as np
from typing import List, Tuple
import json
import time
from datetime import datetime
import os
#import sys
#sys.path.append("YOUR DIRECTORY HERE IF NEEDED")
import CSV_to_list

def get_char_freq(phrase: str) -> np.ndarray:
    """Convert a phrase to a frequency array of characters, including spaces and punctuation."""
    freq = np.zeros(29, dtype=np.int16)
    for char in phrase.lower():
        if char.isalpha():
            freq[ord(char) - ord('a')] += 1
        elif char == " ":
            freq[26] += 1
        elif char == "'":
            freq[27] += 1
        elif char == "-":
            freq[28] += 1
    return freq

def preprocess_wordbank(wordbank: List[str], target_freq: np.ndarray) -> List[Tuple[str, np.ndarray]]:
    """Preprocess wordbank to filter and cache frequency arrays."""
    processed_bank = []
    target_letters = set(i for i, freq in enumerate(target_freq) if freq > 0)
    
    for word in wordbank:
        word_freq = get_char_freq(word)
        if all(i in target_letters for i, freq in enumerate(word_freq) if freq > 0):
            processed_bank.append((word, word_freq))
    
    return sorted(processed_bank, key=lambda x: -np.sum(x[1]))

class AnagramFinder:
    def __init__(self, checkpoint_dir="checkpoints"):
        self.checkpoint_dir = checkpoint_dir
        self.last_save_time = time.time()
        self.save_interval = 300  # Save every 5 minutes
        os.makedirs(checkpoint_dir, exist_ok=True)
        
    def load_checkpoint(self, target: str) -> Tuple[List[List[str]], int]:
        """Load previous results and search count from checkpoint."""
        checkpoint_file = os.path.join(self.checkpoint_dir, f"checkpoint_{target.replace(' ', '_')}.json")
        if os.path.exists(checkpoint_file):
            with open(checkpoint_file, 'r') as f:
                data = json.load(f)
                return data['results'], data['search_count']
        return [], 0

    def save_checkpoint(self, target: str, results: List[List[str]], search_count: int):
        """Save current results and search count to checkpoint."""
        current_time = time.time()
        if current_time - self.last_save_time >= self.save_interval:
            checkpoint_file = os.path.join(self.checkpoint_dir, f"checkpoint_{target.replace(' ', '_')}.json")
            with open(checkpoint_file, 'w') as f:
                json.dump({
                    'target': target,
                    'results': results,
                    'search_count': search_count,
                    'timestamp': datetime.now().isoformat()
                }, f, indent=2)
            self.last_save_time = current_time
            print(f"\nCheckpoint saved for target '{target}' at {datetime.now().isoformat()}")
            print(f"Current results count: {len(results)}")
            print(f"Searches performed: {search_count}")

    def find_phrase_anagrams(self, target: str, wordbank: List[str], 
                            max_searches: int = 1000, max_matches: int = 3) -> List[List[str]]:
        """Find anagrams with checkpointing and match limiting."""
        target_freq = get_char_freq(target)
        results, search_count = self.load_checkpoint(target)
        
        if len(results) >= max_matches:
            print(f"Already found {len(results)} matches for '{target}' in previous run")
            return results[:max_matches]
        
        processed_bank = preprocess_wordbank(wordbank, target_freq)
        space_freq = get_char_freq(" ")
        
        def recursive_search(current_words: List[str], remaining_freq: np.ndarray, 
                            start_idx: int, spaces_needed: int) -> None:
            """Recursive helper using remaining frequency approach."""
            nonlocal search_count
            
            if len(results) >= max_matches or search_count > max_searches:
                return
                
            if np.any(remaining_freq < 0) or spaces_needed < 0:
                return
                
            if np.all(remaining_freq == 0) and spaces_needed == 0:
                results.append(current_words.copy())
                print(f"\nNew match found for '{target}': {' '.join(current_words)}")
                self.save_checkpoint(target, results, search_count)
                return
                
            for i in range(start_idx, len(processed_bank)):
                word, word_freq = processed_bank[i]
                search_count += 1
                
                if np.sum(word_freq) > np.sum(remaining_freq) - spaces_needed:
                    continue
                    
                new_remaining = remaining_freq - word_freq
                if len(current_words) > 0:
                    new_remaining = new_remaining - space_freq
                    new_spaces = spaces_needed - 1
                else:
                    new_spaces = spaces_needed
                    
                current_words.append(word)
                recursive_search(current_words, new_remaining, i + 1, new_spaces)
                current_words.pop()
                
                self.save_checkpoint(target, results, search_count)
        
        initial_spaces = target.count(' ')
        print(f"\nStarting search for '{target}'...")
        print(f"Continuing from previous search count: {search_count}")
        print(f"Previous matches found: {len(results)}")
        
        recursive_search([], target_freq, 0, initial_spaces)
        self.save_checkpoint(target, results, search_count)
        
        return results[:max_matches]

def find_multiple_anagrams(targets: List[str], wordbank: List[str], max_matches: int = 3, max_searches: int = 1000) -> List[Tuple[str, List[List[str]]]]:
    """Find anagrams for multiple target phrases with checkpointing."""
    finder = AnagramFinder()
    results = []
    for target in targets:
        matches = finder.find_phrase_anagrams(target, wordbank, max_matches=max_matches, max_searches=max_searches)
        results.append((target, matches))
    return results

def __main__():
    target_bank = CSV_to_list.csv_to_list("Math Anagram Targets.csv", 'utf-8', True)
    source_bank = CSV_to_list.csv_to_list("Math Anagram Sources.csv", 'utf-8', True)
    results = find_multiple_anagrams(target_bank, source_bank, max_matches = 50, max_searches=1000000)
    
    for target, matches in results:
        print(f"\nTarget: {target}")
        if not matches:
            print("No matches found")
        else:
            for match in matches:
                print(f"Match: {' '.join(match)}")

__main__()
# Out:
# Available columns: ['Word']
# Applied remove_accents()
# Allegedly wrote to csv
# Available columns: ['Word']
# Applied remove_accents()
# Allegedly wrote to csv
#
# Starting search for 'Word'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'Word': Word
#
# New match found for 'Word': word
#
# Starting search for 'Irrational function'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'Irrational function': irrational function
#
# New match found for 'Irrational function': irrational function
#
# Starting search for 'taylor expansion'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'taylor expansion': explanations Roy
#
# New match found for 'taylor expansion': explorations any
#
# New match found for 'taylor expansion': explorations nay
#
# New match found for 'taylor expansion': explanation rosy
#
# New match found for 'taylor expansion': explanatory ions
#
# New match found for 'taylor expansion': exploration nays
#
# New match found for 'taylor expansion': personality axon
#
# New match found for 'taylor expansion': relaxations pony
#
# New match found for 'taylor expansion': explanation rosy
#
# New match found for 'taylor expansion': personality axon
#
# New match found for 'taylor expansion': exploration nays
#
# New match found for 'taylor expansion': expansion Taylor
#
# New match found for 'taylor expansion': expansion Taylor
#
# Starting search for 'euler's number'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'euler's number': lumber's enure
#
# New match found for 'euler's number': number's Euler
#
# New match found for 'euler's number': rumble's enure
#
# New match found for 'euler's number': lemur's Reuben
#
# Starting search for 'pointwise convergence'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# Starting search for 'absolute convergence'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'absolute convergence': convergence absolute
#
# Starting search for 'laplacian operator'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'laplacian operator': operational carpal
#
# New match found for 'laplacian operator': preparation Callao
#
# New match found for 'laplacian operator': preparation Callao
#
# Starting search for 'laplacian eigenspectrum'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# Starting search for 'matrix eigenvalues'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'matrix eigenvalues': reevaluating mixes
#
# New match found for 'matrix eigenvalues': eigenvalues matrix
#
# New match found for 'matrix eigenvalues': reevaluates mixing
#
# New match found for 'matrix eigenvalues': eigenvalue Marxist
#
# Starting search for 'complex field'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'complex field': compelled fix
#
# New match found for 'complex field': compelled fix
#
# New match found for 'complex field': compiled flex
#
# New match found for 'complex field': complied flex
#
# New match found for 'complex field': clomped Felix
#
# New match found for 'complex field': complex Fidel
#
# New match found for 'complex field': complex field
#
# New match found for 'complex field': complex filed
#
# New match found for 'complex field': complex flied
#
# New match found for 'complex field': complex Fidel
#
# New match found for 'complex field': complex field
#
# New match found for 'complex field': complex filed
#
# New match found for 'complex field': complex flied
#
# Starting search for 'fourier transform'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'fourier transform': transform Fourier
#
# New match found for 'fourier transform': transform Fourier
#
# Starting search for 'fast fourier transform'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'fast fourier transform': frustrations forearm F
#
# New match found for 'fast fourier transform': frustrations forearm f
#
# New match found for 'fast fourier transform': frustrations Farmer of
#
# New match found for 'fast fourier transform': frustrations farmer of
#
# New match found for 'fast fourier transform': frustrations femora Fr
#
# New match found for 'fast fourier transform': frustrations former fa
#
# New match found for 'fast fourier transform': frustrations framer of
#
# New match found for 'fast fourier transform': frustrations reform fa
#
# New match found for 'fast fourier transform': frustrations reform fa
#
# New match found for 'fast fourier transform': frustrations farmer of
#
# New match found for 'fast fourier transform': frustrations frame for
#
# New match found for 'fast fourier transform': frustrations frame fro
#
# New match found for 'fast fourier transform': frustrations offer Mar
#
# New match found for 'fast fourier transform': frustrations offer arm
#
# New match found for 'fast fourier transform': frustrations offer mar
#
# New match found for 'fast fourier transform': frustrations offer ram
#
# New match found for 'fast fourier transform': frustrations rearm off
#
# New match found for 'fast fourier transform': frustrations frame for
#
# New match found for 'fast fourier transform': frustrations frame fro
#
# New match found for 'fast fourier transform': frustrations fare form
#
# New match found for 'fast fourier transform': frustrations fare from
#
# New match found for 'fast fourier transform': frustrations fare form
#
# New match found for 'fast fourier transform': frustrations farm fore
#
# New match found for 'fast fourier transform': frustrations fear form
#
# New match found for 'fast fourier transform': frustrations fear from
#
# New match found for 'fast fourier transform': frustrations fear form
#
# New match found for 'fast fourier transform': frustrations fore farm
#
# New match found for 'fast fourier transform': frustrations form fear
#
# New match found for 'fast fourier transform': frustrations form fare
#
# New match found for 'fast fourier transform': frustrations from fear
#
# New match found for 'fast fourier transform': frustrations from fare
#
# New match found for 'fast fourier transform': frustrations form fear
#
# New match found for 'fast fourier transform': frustrations form fare
#
# New match found for 'fast fourier transform': reformations farts fur
#
# New match found for 'fast fourier transform': reformations farts fur
#
# New match found for 'fast fourier transform': reformations frats fur
#
# New match found for 'fast fourier transform': reformations frats fur
#
# New match found for 'fast fourier transform': reformations rafts fur
#
# New match found for 'fast fourier transform': reformations rafts fur
#
# New match found for 'fast fourier transform': reformations ruffs Art
#
# New match found for 'fast fourier transform': reformations ruffs art
#
# New match found for 'fast fourier transform': reformations ruffs rat
#
# New match found for 'fast fourier transform': reformations ruffs tar
#
# New match found for 'fast fourier transform': reformations ruffs rat
#
# New match found for 'fast fourier transform': reformations turfs far
#
# New match found for 'fast fourier transform': reformations arts ruff
#
# New match found for 'fast fourier transform': reformations fart furs
#
# New match found for 'fast fourier transform': reformations fart surf
#
# New match found for 'fast fourier transform': reformations frat furs
#
# New match found for 'fast fourier transform': reformations frat surf
#
# Starting search for 'discrete fourier transform'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'discrete fourier transform': counterfeiters mirrors fad
#
# New match found for 'discrete fourier transform': counterfeiters ramrods Fri
#
# New match found for 'discrete fourier transform': counterfeiters ramrods fir
#
# New match found for 'discrete fourier transform': counterfeiters ardors firm
#
# New match found for 'discrete fourier transform': counterfeiters ardors firm
#
# New match found for 'discrete fourier transform': counterfeiters friars dorm
#
# New match found for 'discrete fourier transform': counterfeiters mirror fads
#
# New match found for 'discrete fourier transform': counterfeiters ramrod firs
#
# New match found for 'discrete fourier transform': counterfeiters mirror fads
#
# New match found for 'discrete fourier transform': counterfeiters ardor firms
#
# New match found for 'discrete fourier transform': counterfeiters dorms friar
#
# Starting search for 'computationally irreducible'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# Starting search for 'irreducible variety'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'irreducible variety': durability receiver
#
# New match found for 'irreducible variety': durability receiver
#
# Starting search for 'irreducible algebraic variety'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'irreducible algebraic variety': irretrievable bicycled Auriga
#
# New match found for 'irreducible algebraic variety': irretrievable acerbic gaudily
#
# Starting search for 'difference of squares'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'difference of squares': differences square of
#
# New match found for 'difference of squares': differences square of
#
# New match found for 'difference of squares': differences fores qua
#
# New match found for 'difference of squares': frequencies affords E
#
# New match found for 'difference of squares': frequencies affords e
#
# New match found for 'difference of squares': frequencies fedoras F
#
# New match found for 'difference of squares': frequencies fedoras f
#
# New match found for 'difference of squares': frequencies afford Es
#
# New match found for 'difference of squares': frequencies afford Se
#
# New match found for 'difference of squares': frequencies afford es
#
# New match found for 'difference of squares': frequencies offers ad
#
# New match found for 'difference of squares': frequencies offers ad
#
# New match found for 'difference of squares': frequencies afford Es
#
# New match found for 'difference of squares': frequencies afford Se
#
# New match found for 'difference of squares': frequencies afford es
#
# New match found for 'difference of squares': frequencies Afros Fed
#
# New match found for 'difference of squares': frequencies Afros fed
#
# New match found for 'difference of squares': frequencies dares off
#
# New match found for 'difference of squares': frequencies dears off
#
# New match found for 'difference of squares': frequencies doffs Rae
#
# New match found for 'difference of squares': frequencies doffs are
#
# New match found for 'difference of squares': frequencies doffs ear
#
# New match found for 'difference of squares': frequencies doffs era
#
# New match found for 'difference of squares': frequencies doffs ear
#
# New match found for 'difference of squares': frequencies doffs era
#
# New match found for 'difference of squares': frequencies fades for
#
# New match found for 'difference of squares': frequencies fades fro
#
# New match found for 'difference of squares': frequencies fores fad
#
# New match found for 'difference of squares': frequencies offer ads
#
# New match found for 'difference of squares': frequencies offer sad
#
# New match found for 'difference of squares': frequencies offer sad
#
# New match found for 'difference of squares': frequencies reads off
#
# New match found for 'difference of squares': frequencies Afro Feds
#
# New match found for 'difference of squares': frequencies Afro feds
#
# New match found for 'difference of squares': frequencies Ares doff
#
# New match found for 'difference of squares': frequencies Dare offs
#
# New match found for 'difference of squares': frequencies Feds fora
#
# New match found for 'difference of squares': frequencies Ford safe
#
# New match found for 'difference of squares': frequencies Ford safe
#
# New match found for 'difference of squares': frequencies Fred oafs
#
# New match found for 'difference of squares': frequencies Fred sofa
#
# New match found for 'difference of squares': frequencies Fred sofa
#
# New match found for 'difference of squares': frequencies ares doff
#
# New match found for 'difference of squares': frequencies dare offs
#
# New match found for 'difference of squares': frequencies dear offs
#
# New match found for 'difference of squares': frequencies doff ears
#
# New match found for 'difference of squares': frequencies doff eras
#
# New match found for 'difference of squares': frequencies doff sear
#
# New match found for 'difference of squares': frequencies doff sera
#
# New match found for 'difference of squares': frequencies fads fore
#
# Starting search for 'partial differentiation'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'partial differentiation': differentiation partial
#
# New match found for 'partial differentiation': differentiation partial
#
# Starting search for 'point set topology'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'point set topology': penologist potty O
#
# New match found for 'point set topology': penologist potty o
#
# New match found for 'point set topology': penologist typo to
#
# New match found for 'point set topology': penologist opt toy
#
# New match found for 'point set topology': penologist opt toy
#
# New match found for 'point set topology': penologist pot toy
#
# New match found for 'point set topology': penologist pot toy
#
# New match found for 'point set topology': penologist top toy
#
# New match found for 'point set topology': penologist top toy
#
# New match found for 'point set topology': penologist toy top
#
# New match found for 'point set topology': penologist toy pot
#
# New match found for 'point set topology': penologist toy opt
#
# New match found for 'point set topology': penologist top toy
#
# New match found for 'point set topology': penologist pot toy
#
# New match found for 'point set topology': penologist toy opt
#
# New match found for 'point set topology': logotypes option T
#
# New match found for 'point set topology': logotypes option t
#
# New match found for 'point set topology': logotypes potion T
#
# New match found for 'point set topology': logotypes potion t
#
# New match found for 'point set topology': logotypes option T
#
# New match found for 'point set topology': logotypes option t
#
# New match found for 'point set topology': logotypes Tonto pi
#
# New match found for 'point set topology': logotypes pinto to
#
# New match found for 'point set topology': logotypes piton to
#
# New match found for 'point set topology': logotypes point to
#
# New match found for 'point set topology': logotypes Otto nip
#
# New match found for 'point set topology': logotypes Otto pin
#
# New match found for 'point set topology': logotypes Otto pin
#
# New match found for 'point set topology': logotypes Pitt Ono
#
# New match found for 'point set topology': logotypes Toni opt
#
# New match found for 'point set topology': logotypes Toni pot
#
# New match found for 'point set topology': logotypes Toni top
#
# New match found for 'point set topology': logotypes Toni top
#
# New match found for 'point set topology': logotypes Toni pot
#
# New match found for 'point set topology': logotypes Toni opt
#
# New match found for 'point set topology': logotypes Toto nip
#
# New match found for 'point set topology': logotypes Toto pin
#
# New match found for 'point set topology': logotypes Toto pin
#
# New match found for 'point set topology': logotypes into opt
#
# New match found for 'point set topology': logotypes into pot
#
# New match found for 'point set topology': logotypes into top
#
# New match found for 'point set topology': logotypes into top
#
# New match found for 'point set topology': logotypes into pot
#
# New match found for 'point set topology': logotypes into opt
#
# New match found for 'point set topology': logotypes onto pit
#
# New match found for 'point set topology': logotypes onto tip
#
# New match found for 'point set topology': logotypes onto tip
#
# New match found for 'point set topology': logotypes onto pit
#
# New match found for 'point set topology': logotypes pint too
#
# New match found for 'point set topology': logotypes toot nip
#
# Starting search for 'nonintegrable domain'...
# Continuing from previous search count: 0
# Previous matches found: 0
#
# New match found for 'nonintegrable domain': abandonment religion
#
# New match found for 'nonintegrable domain': abandonment religion
#
# Target: Word
# Match: Word
# Match: word
#
# Target: Irrational function
# Match: irrational function
# Match: irrational function
#
# Target: taylor expansion
# Match: explanations Roy
# Match: explorations any
# Match: explorations nay
# Match: explanation rosy
# Match: explanatory ions
# Match: exploration nays
# Match: personality axon
# Match: relaxations pony
# Match: explanation rosy
# Match: personality axon
# Match: exploration nays
# Match: expansion Taylor
# Match: expansion Taylor
#
# Target: euler's number
# Match: lumber's enure
# Match: number's Euler
# Match: rumble's enure
# Match: lemur's Reuben
#
# Target: pointwise convergence
# No matches found
#
# Target: absolute convergence
# Match: convergence absolute
#
# Target: laplacian operator
# Match: operational carpal
# Match: preparation Callao
# Match: preparation Callao
#
# Target: laplacian eigenspectrum
# No matches found
#
# Target: matrix eigenvalues
# Match: reevaluating mixes
# Match: eigenvalues matrix
# Match: reevaluates mixing
# Match: eigenvalue Marxist
#
# Target: complex field
# Match: compelled fix
# Match: compelled fix
# Match: compiled flex
# Match: complied flex
# Match: clomped Felix
# Match: complex Fidel
# Match: complex field
# Match: complex filed
# Match: complex flied
# Match: complex Fidel
# Match: complex field
# Match: complex filed
# Match: complex flied
#
# Target: fourier transform
# Match: transform Fourier
# Match: transform Fourier
#
# Target: fast fourier transform
# Match: frustrations forearm F
# Match: frustrations forearm f
# Match: frustrations Farmer of
# Match: frustrations farmer of
# Match: frustrations femora Fr
# Match: frustrations former fa
# Match: frustrations framer of
# Match: frustrations reform fa
# Match: frustrations reform fa
# Match: frustrations farmer of
# Match: frustrations frame for
# Match: frustrations frame fro
# Match: frustrations offer Mar
# Match: frustrations offer arm
# Match: frustrations offer mar
# Match: frustrations offer ram
# Match: frustrations rearm off
# Match: frustrations frame for
# Match: frustrations frame fro
# Match: frustrations fare form
# Match: frustrations fare from
# Match: frustrations fare form
# Match: frustrations farm fore
# Match: frustrations fear form
# Match: frustrations fear from
# Match: frustrations fear form
# Match: frustrations fore farm
# Match: frustrations form fear
# Match: frustrations form fare
# Match: frustrations from fear
# Match: frustrations from fare
# Match: frustrations form fear
# Match: frustrations form fare
# Match: reformations farts fur
# Match: reformations farts fur
# Match: reformations frats fur
# Match: reformations frats fur
# Match: reformations rafts fur
# Match: reformations rafts fur
# Match: reformations ruffs Art
# Match: reformations ruffs art
# Match: reformations ruffs rat
# Match: reformations ruffs tar
# Match: reformations ruffs rat
# Match: reformations turfs far
# Match: reformations arts ruff
# Match: reformations fart furs
# Match: reformations fart surf
# Match: reformations frat furs
# Match: reformations frat surf
#
# Target: discrete fourier transform
# Match: counterfeiters mirrors fad
# Match: counterfeiters ramrods Fri
# Match: counterfeiters ramrods fir
# Match: counterfeiters ardors firm
# Match: counterfeiters ardors firm
# Match: counterfeiters friars dorm
# Match: counterfeiters mirror fads
# Match: counterfeiters ramrod firs
# Match: counterfeiters mirror fads
# Match: counterfeiters ardor firms
# Match: counterfeiters dorms friar
#
# Target: computationally irreducible
# No matches found
#
# Target: irreducible variety
# Match: durability receiver
# Match: durability receiver
#
# Target: irreducible algebraic variety
# Match: irretrievable bicycled Auriga
# Match: irretrievable acerbic gaudily
#
# Target: difference of squares
# Match: differences square of
# Match: differences square of
# Match: differences fores qua
# Match: frequencies affords E
# Match: frequencies affords e
# Match: frequencies fedoras F
# Match: frequencies fedoras f
# Match: frequencies afford Es
# Match: frequencies afford Se
# Match: frequencies afford es
# Match: frequencies offers ad
# Match: frequencies offers ad
# Match: frequencies afford Es
# Match: frequencies afford Se
# Match: frequencies afford es
# Match: frequencies Afros Fed
# Match: frequencies Afros fed
# Match: frequencies dares off
# Match: frequencies dears off
# Match: frequencies doffs Rae
# Match: frequencies doffs are
# Match: frequencies doffs ear
# Match: frequencies doffs era
# Match: frequencies doffs ear
# Match: frequencies doffs era
# Match: frequencies fades for
# Match: frequencies fades fro
# Match: frequencies fores fad
# Match: frequencies offer ads
# Match: frequencies offer sad
# Match: frequencies offer sad
# Match: frequencies reads off
# Match: frequencies Afro Feds
# Match: frequencies Afro feds
# Match: frequencies Ares doff
# Match: frequencies Dare offs
# Match: frequencies Feds fora
# Match: frequencies Ford safe
# Match: frequencies Ford safe
# Match: frequencies Fred oafs
# Match: frequencies Fred sofa
# Match: frequencies Fred sofa
# Match: frequencies ares doff
# Match: frequencies dare offs
# Match: frequencies dear offs
# Match: frequencies doff ears
# Match: frequencies doff eras
# Match: frequencies doff sear
# Match: frequencies doff sera
# Match: frequencies fads fore
#
# Target: partial differentiation
# Match: differentiation partial
# Match: differentiation partial
#
# Target: point set topology
# Match: penologist potty O
# Match: penologist potty o
# Match: penologist typo to
# Match: penologist opt toy
# Match: penologist opt toy
# Match: penologist pot toy
# Match: penologist pot toy
# Match: penologist top toy
# Match: penologist top toy
# Match: penologist toy top
# Match: penologist toy pot
# Match: penologist toy opt
# Match: penologist top toy
# Match: penologist pot toy
# Match: penologist toy opt
# Match: logotypes option T
# Match: logotypes option t
# Match: logotypes potion T
# Match: logotypes potion t
# Match: logotypes option T
# Match: logotypes option t
# Match: logotypes Tonto pi
# Match: logotypes pinto to
# Match: logotypes piton to
# Match: logotypes point to
# Match: logotypes Otto nip
# Match: logotypes Otto pin
# Match: logotypes Otto pin
# Match: logotypes Pitt Ono
# Match: logotypes Toni opt
# Match: logotypes Toni pot
# Match: logotypes Toni top
# Match: logotypes Toni top
# Match: logotypes Toni pot
# Match: logotypes Toni opt
# Match: logotypes Toto nip
# Match: logotypes Toto pin
# Match: logotypes Toto pin
# Match: logotypes into opt
# Match: logotypes into pot
# Match: logotypes into top
# Match: logotypes into top
# Match: logotypes into pot
# Match: logotypes into opt
# Match: logotypes onto pit
# Match: logotypes onto tip
# Match: logotypes onto tip
# Match: logotypes onto pit
# Match: logotypes pint too
# Match: logotypes toot nip
#
# Target: nonintegrable domain
# Match: abandonment religion
# Match: abandonment religion
